# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
avocado_df=pd.read_csv ('C:\\Users\\jlvly\\Downloads\\avocado\\avocado.csv')
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado_df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocado_df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
avocado_df = avocado_df.sort_values("Date")

# %%
avocado_df['Date']= pd.to_datetime(avocado_df['Date'])

# %%
avocado_df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569          51 2015-01-04          1.75      27365.89     9307.34
# 9593           51 2015-01-04          1.49      17723.17     1189.35
# 10009          51 2015-01-04          1.68       2896.72      161.68
# 1819           51 2015-01-04          1.52      54956.80     3013.04
# 9333           51 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574            0 2018-03-25          1.36     908202.13   142681.06
# 9018            0 2018-03-25          0.70    9010588.32  3999735.71
# 18141           0 2018-03-25          1.42     163496.70    29253.30
# 17673           0 2018-03-25          1.70     190257.38    29644.09
# 8814            0 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avocado_df.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
avocado_df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
avocado_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avocado_df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avocado_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 11569 to 8814
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 2.1+ MB

# %%
avocado_df['region'].value_counts()
# Out:
# Nashville              338
# Roanoke                338
# PhoenixTucson          338
# TotalUS                338
# Southeast              338
# Northeast              338
# Orlando                338
# LasVegas               338
# Philadelphia           338
# Tampa                  338
# Jacksonville           338
# SouthCarolina          338
# Plains                 338
# CincinnatiDayton       338
# Spokane                338
# GreatLakes             338
# Sacramento             338
# Louisville             338
# Syracuse               338
# Houston                338
# Albany                 338
# Pittsburgh             338
# HartfordSpringfield    338
# SanDiego               338
# Midsouth               338
# Boise                  338
# Denver                 338
# NewYork                338
# Charlotte              338
# GrandRapids            338
# Atlanta                338
# NorthernNewEngland     338
# California             338
# NewOrleansMobile       338
# ...

# %%
sns.countplot(avocado_df['year'])

# %%
avocado_df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
sns.countplot(avocado_df['type'])

# %%
avocado_df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.figure(figsize=(16,7))
sns.heatmap(avocado_df.corr(),annot=True,cmap='YlGnBu')

# %%
avocado_df.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.375590
# 2016    1.338640
# 2017    1.515128
# 2018    1.347531
# Name: AveragePrice, dtype: float64

# %%
avPrice_mean=avocado_df['AveragePrice'].mean()
avPrice_mean
# Out:
# 1.4059784097758845

# %%
avocado_df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %%
sns.barplot(avocado_df['year'],avocado_df['AveragePrice'],data=avocado_df)

# %%
avocado_df.skew(axis=0,skipna=True)
# Out:
# Unnamed: 0       0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
skewed_col=('Total Volume','4046','4225','4770' ,'Total Bags','Small Bags','Large Bags','XLarge Bags' )
            
for col in skewed_col:
    if avocado_df.skew().loc[col]>0.55:
        avocado_df[col]=np.log1p(avocado_df[col])

# %%
avocado_df.skew(axis=0,skipna=True)
# Out:
# Unnamed: 0      0.108334
# AveragePrice    0.580303
# Total Volume    0.088098
# 4046           -0.328195
# 4225           -0.486654
# 4770            0.099986
# Total Bags     -0.218874
# Small Bags     -0.622148
# Large Bags     -0.547765
# XLarge Bags     1.176494
# year            0.215339
# dtype: float64

# %%
avocado_df['XLarge Bags']=np.log1p(avocado_df['XLarge Bags'])

# %%
avocado_df.skew(axis=0,skipna=True)
# Out:
# Unnamed: 0      0.108334
# AveragePrice    0.580303
# Total Volume    0.088098
# 4046           -0.328195
# 4225           -0.486654
# 4770            0.099986
# Total Bags     -0.218874
# Small Bags     -0.622148
# Large Bags     -0.547765
# XLarge Bags     0.840536
# year            0.215339
# dtype: float64

# %%
avocado_df['XLarge Bags']=np.log1p(avocado_df['XLarge Bags'])

# %%
avocado_dataset=pd.get_dummies(avocado_df,columns=['type','region'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
avocado_dataset.dtypes
# Out:
# Unnamed: 0                          int64
# Date                       datetime64[ns]
# AveragePrice                      float64
# Total Volume                      float64
# 4046                              float64
#                                 ...
# region_Syracuse                     uint8
# region_Tampa                        uint8
# region_TotalUS                      uint8
# region_West                         uint8
# region_WestTexNewMexico             uint8
# Length: 68, dtype: object

# %%
#removing Date column
avocado_dataset.drop(['Date'],axis=1,inplace=True)

# %%
avocado_dataset.dtypes
# Out:
# Unnamed: 0                   int64
# AveragePrice               float64
# Total Volume               float64
# 4046                       float64
# 4225                       float64
#                             ...
# region_Syracuse              uint8
# region_Tampa                 uint8
# region_TotalUS               uint8
# region_West                  uint8
# region_WestTexNewMexico      uint8
# Length: 67, dtype: object

# %%
X=avocado_dataset.drop('AveragePrice',axis=1)
y=avocado_dataset["AveragePrice"]

# %%
y
# Out:
# 11569    1.75
# 9593     1.49
# 10009    1.68
# 1819     1.52
# 9333     1.64
#          ...
# 8574     1.36
# 9018     0.70
# 18141    1.42
# 17673    1.70
# 8814     1.34
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.07683804, -1.24574731, -0.83128563, ..., -0.13808191,
#         -0.14157373, -0.13749198],
#        [-1.37053662,  1.42928079,  1.55360426, ..., -0.13808191,
#         -0.14157373, -0.13749198],
#        [ 0.57001125, -1.09904022, -1.14866432, ..., -0.13808191,
#         -0.14157373, -0.13749198],
#        ...,
#        [-1.43522155,  0.82494611, -0.16712012, ..., -0.13808191,
#         -0.14157373, -0.13749198],
#        [ 1.28154547, -0.86720456, -1.02421565, ..., -0.13808191,
#         -0.14157373, -0.13749198],
#        [-0.91774212,  0.47275087, -0.02688001, ..., -0.13808191,
#         -0.14157373, -0.13749198]])

# %%
y_train
# Out:
# 13204    1.33
# 2395     1.13
# 12798    1.60
# 237      1.25
# 14999    1.95
#          ...
# 16330    2.00
# 17172    1.12
# 210      1.01
# 9638     1.23
# 6527     1.50
# Name: AveragePrice, Length: 12774, dtype: float64

# %%
#scaler=StandardScaler()
#x_train=scaler.fit_transform(x_train)
#x_test=scaler.fit_transform(x_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
pred=model.predict(X_test)
pred
# Out:
# array([1.61905542, 0.94245149, 1.21329229, ..., 1.48102609, 1.16397817,
#        0.98692312])

# %%
from sklearn.metrics import r2_score
score=r2_score(model.predict(X_test),y_test)
score
# Out:
# 0.5566943554341391

# %%
from sklearn.linear_model import Lasso

# %%
model=[]
score=[]
cvs=[]
for i in [LinearRegression(),KNeighborsRegressor(n_neighbors=10),DecisionTreeRegressor(criterion='mse'),Lasso(alpha=0.001)]:
    k=i
    model.append(i)
    print("\n")
    print("model calculation for ",i,"are:")
    k.fit(X_train,y_train)
    k.score(X_train,y_train)
    pred=k.predict(X_test)
    print(pred)
    rscore=r2_score(k.predict(X_test),y_test)
    print("r2 score is",rscore)
    score.append(rscore)
    cv_score=cross_val_score(k,X,y,cv=5).mean()
    print('cv score is',cv_score)
    cvs.append(cv_score)
# Out:
# model calculation for  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) are:
# [1.61905542 0.94245149 1.21329229 ... 1.48102609 1.16397817 0.98692312]
# r2 score is 0.5566943554341391
# cv score is 0.6247261528315543
#
#
# model calculation for  KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform') are:
# [1.479 0.996 1.373 ... 1.684 1.408 1.199]
# r2 score is 0.7836196798253223
# cv score is 0.32182034309061497
#
#
# model calculation for  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
# ...

# %%
result=pd.DataFrame({'Model':['LinearRegression','KNeighborsRegressor','DecisionTreeRegressor','Lasso'],'R2 score':[0.5566943554341391,0.7836196798253223,0.8009881112128406,0.5241477876081505],'CV score':[ 0.6247261528315543,0.32182034309061497,0.24503004830314587,0.5896629291939781]})
result
# Out:
#                    Model  R2 score  CV score
# 0       LinearRegression  0.556694  0.624726
# 1    KNeighborsRegressor  0.783620  0.321820
# 2  DecisionTreeRegressor  0.800988  0.245030
# 3                  Lasso  0.524148  0.589663

# %%
#DecisiontreeRegressor is the best model, so we are saving it

# %%
from sklearn.externals import joblib 
  

joblib.dump(model,'avocado.pkl') 
  
model_from_joblib = joblib.load('avocado.pkl')

# %%
#REGION based PREDICTION

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve

# %%
avocado_df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume       4046  \
# 11569          51 2015-01-04          1.75     10.217089   9.138666
# 9593           51 2015-01-04          1.49      9.782685   7.082003
# 10009          51 2015-01-04          1.68      7.971679   5.091785
# 1819           51 2015-01-04          1.52     10.914321   8.011037
# 9333           51 2015-01-04          1.64      7.317292   0.819780
# ...           ...        ...           ...           ...        ...
# 8574            0 2018-03-25          1.36     13.719223  11.868374
# 9018            0 2018-03-25          0.70     16.013911  15.201739
# 18141           0 2018-03-25          1.42     12.004554  10.283782
# 17673           0 2018-03-25          1.70     12.156138  10.297052
# 8814            0 2018-03-25          1.34     14.389186  11.065184
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avocado_df.drop(['Date'],inplace=True,axis=1)

# %%
avocado_df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume       4046       4225  \
# 11569          51          1.75     10.217089   9.138666   8.254740
# 9593           51          1.49      9.782685   7.082003   9.656901
# 10009          51          1.68      7.971679   5.091785   5.337346
# 1819           51          1.52     10.914321   8.011037  10.476101
# 9333           51          1.64      7.317292   0.819780   7.030415
# ...           ...           ...           ...        ...        ...
# 8574            0          1.36     13.719223  11.868374  13.045779
# 9018            0          0.70     16.013911  15.201739  13.781530
# 18141           0          1.42     12.004554  10.283782   8.533271
# 17673           0          1.70     12.156138  10.297052  11.170197
# 8814            0          1.34     14.389186  11.065184  13.719720
#
#             4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 11569   6.423701    9.517785    9.477470    6.288527     0.000000
# ...

# %%
avocado_dff=pd.get_dummies(avocado_df,columns=['type'])

# %%
a=avocado_dff.drop('region',axis=1)
b=avocado_dff["region"]

# %%
a
# Out:
#        Unnamed: 0  AveragePrice  Total Volume       4046       4225  \
# 11569          51          1.75     10.217089   9.138666   8.254740
# 9593           51          1.49      9.782685   7.082003   9.656901
# 10009          51          1.68      7.971679   5.091785   5.337346
# 1819           51          1.52     10.914321   8.011037  10.476101
# 9333           51          1.64      7.317292   0.819780   7.030415
# ...           ...           ...           ...        ...        ...
# 8574            0          1.36     13.719223  11.868374  13.045779
# 9018            0          0.70     16.013911  15.201739  13.781530
# 18141           0          1.42     12.004554  10.283782   8.533271
# 17673           0          1.70     12.156138  10.297052  11.170197
# 8814            0          1.34     14.389186  11.065184  13.719720
#
#             4770  Total Bags  Small Bags  Large Bags  XLarge Bags  year  \
# 11569   6.423701    9.517785    9.477470    6.288527     0.000000  2015
# ...

# %%
b
# Out:
# 11569             Southeast
# 9593                Chicago
# 10009    HarrisburgScranton
# 1819             Pittsburgh
# 9333                  Boise
#                 ...
# 8574                Chicago
# 9018           SouthCentral
# 18141          SouthCentral
# 17673            California
# 8814                NewYork
# Name: region, Length: 18249, dtype: object

# %%
#bb=pd.get_dummies(b)

# %%
#bb

# %%
from sklearn.model_selection import train_test_split 
a_train, a_test, b_train, b_test = train_test_split( a, b, test_size = 0.25, random_state = 85)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
a_train=scaler.fit_transform(a_train)
a_test=scaler.fit_transform(a_test)

# %%
lr=LogisticRegression()
lr.fit(a_train,b_train)
pred=lr.predict(a_test)
acc_score=accuracy_score(pred,b_test)
acc_score
# Out:
# 0.5614727153188692

# %%
from sklearn.model_selection import GridSearchCV
sv=SVC()
parameters={'kernel':('linear','rbf'),'C':[1,10]}
gd=GridSearchCV(sv,parameters)
gd.fit(a_train,b_train)
gd.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
from sklearn.model_selection import GridSearchCV
kn=KNeighborsClassifier()
parameters={'n_neighbors':(1,10)}
gd=GridSearchCV(kn,parameters)
gd.fit(a_train,b_train)
gd.best_params_
# Out:
# {'n_neighbors': 1}

# %%
dt=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy')}
gd=GridSearchCV(dt,parameters)
gd.fit(a_train,b_train)
gd.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
model=[]
score=[]
cvs=[]


for i in [LogisticRegression(),KNeighborsClassifier(n_neighbors=10),DecisionTreeClassifier(criterion='entropy'),SVC(C=10,kernel='rbf')]:
    k=i
    model.append(i)
    print("\n")
    print("model calculation for ",i,"are:")
    k.fit(a_train,b_train)
    k.score(a_train,b_train)
    pred=k.predict(a_test)
    print(pred)
    AS=accuracy_score(pred,b_test)
    print("accuracy score is",AS)
    score.append(AS)
    cv_score=cross_val_score(k,a,b,cv=5,scoring='accuracy').mean()
    print('cv score is',cv_score)
    cvs.append(cv_score)
    print("")
    cm=confusion_matrix(pred,b_test)
    print(cm)
    print("")
    print(classification_report(pred,b_test))
    print("\n")
# Out:
# model calculation for  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False) are:
# ['Albany' 'DallasFtWorth' 'Atlanta' ... 'TotalUS' 'StLouis'
#  'HarrisburgScranton']
# accuracy score is 0.5614727153188692
# cv score is 0.15370442643321308
#
# [[ 69   0   0 ...   0   0   0]
#  [  0  32   0 ...   0   0   2]
#  [  0   0  55 ...   0   0   1]
#  ...
#  [  0   0   0 ... 101   1   0]
#  [  0   0   0 ...   1  72   0]
#  [  0   0   9 ...   0   0  23]]
#
#                      precision    recall  f1-score   support
#
#              Albany       0.62      0.74      0.67        93
#             Atlanta       0.41      0.23      0.29       140
# BaltimoreWashington       0.62      0.77      0.69        71
# ...

# %%
#SVC model is best with maximum accuracy so we will save it

# %%
from sklearn.externals import joblib 
  

joblib.dump(sv, 'avocado.pkl') 
  
lr_from_joblib = joblib.load('avocado.pkl')
