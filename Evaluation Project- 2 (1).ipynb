# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('baseball.csv')
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
data=data.rename(columns={'W':'Wins',"R":"Runs","AB":"At-Bat","H":"Hits","2B":"Doubles","3B":"Triples","HR":"Home Run","BB":"Walks","SO":"Strikeout","SB":"Bases Stolen","RA":"Run average","ER":"Earned runs","ERA":"Earned runs average","CG":"Complete game","SHO":"Shutout","SV":"Save","E":"Error"})
data
# Out:
#     Wins  Runs  At-Bat  Hits  Doubles  Triples  Home Run  Walks  Strikeout  \
# 0     95   724    5575  1497      300       42       139    383        973
# 1     83   696    5467  1349      277       44       156    439       1264
# 2     81   669    5439  1395      303       29       141    533       1157
# 3     76   622    5533  1381      260       27       136    404       1231
# 4     74   689    5605  1515      289       49       151    455       1259
# 5     93   891    5509  1480      308       17       232    570       1151
# 6     87   764    5567  1397      272       19       212    554       1227
# 7     81   713    5485  1370      246       20       217    418       1331
# 8     80   644    5485  1383      278       32       167    436       1310
# 9     78   748    5640  1495      294       33       161    478       1148
# 10    88   751    5511  1419      279       32       172    503       1233
# ...

# %%
data.columns
# Out:
# Index(['Wins', 'Runs', 'At-Bat', 'Hits', 'Doubles', 'Triples', 'Home Run',
#        'Walks', 'Strikeout', 'Bases Stolen', 'Run average', 'Earned runs',
#        'Earned runs average', 'Complete game', 'Shutout', 'Save', 'Error'],
#       dtype='object')

# %%
data.shape
# Out:
# (30, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wins                 30 non-null     int64
#  1   Runs                 30 non-null     int64
#  2   At-Bat               30 non-null     int64
#  3   Hits                 30 non-null     int64
#  4   Doubles              30 non-null     int64
#  5   Triples              30 non-null     int64
#  6   Home Run             30 non-null     int64
#  7   Walks                30 non-null     int64
#  8   Strikeout            30 non-null     int64
#  9   Bases Stolen         30 non-null     int64
#  10  Run average          30 non-null     int64
#  11  Earned runs          30 non-null     int64
#  12  Earned runs average  30 non-null     float64
#  13  Complete game        30 non-null     int64
#  14  Shutout              30 non-null     int64
# ...

# %%
data.isnull().sum()
# Out:
# Wins                   0
# Runs                   0
# At-Bat                 0
# Hits                   0
# Doubles                0
# Triples                0
# Home Run               0
# Walks                  0
# Strikeout              0
# Bases Stolen           0
# Run average            0
# Earned runs            0
# Earned runs average    0
# Complete game          0
# Shutout                0
# Save                   0
# Error                  0
# dtype: int64

# %%
data.describe()
# Out:
#              Wins        Runs       At-Bat         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Home Run       Walks   Strikeout  Bases Stolen  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
plt.hist(data["Wins"])
plt.xlabel('Wins')
plt.title('^Distribution plot of no of Wins^')
plt.show()

# %%
data["Wins"].max()
# Out:
# 100

# %%
data[data["Wins"]==100]
# Out:
#     Wins  Runs  At-Bat  Hits  Doubles  Triples  Home Run  Walks  Strikeout  \
# 15   100   647    5484  1386      288       39       137    506       1267
#
#     Bases Stolen  Run average  Earned runs  Earned runs average  \
# 15            69          525          478                 2.94
#
#     Complete game  Shutout  Save  Error
# 15              1       15    62     96

# %%
sns.scatterplot(x = "Error", y = "Wins", data=data)
plt.show()

# %%
sns.scatterplot(x = "Runs", y = "Wins", data=data)
plt.show()

# %%
sns.scatterplot(x = "Home Run", y = "Wins", data=data)
plt.show()

# %%
sns.scatterplot(x = "Walks", y = "Wins", data=data)
plt.show()

# %%
sns.scatterplot(x = "Earned runs", y = "Wins", data=data)
plt.show()

# %%
sns.scatterplot(x = "Run average", y = "Wins", data=data)
plt.show()

# %%
sns.scatterplot(x = "Earned runs average", y = "Wins", data=data)
plt.show()

# %%
data.corr()
# Out:
#                          Wins      Runs    At-Bat      Hits   Doubles  \
# Wins                 1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                 0.430751  1.000000  0.319464  0.482856  0.560084
# At-Bat              -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                 0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles              0.427797  0.560084  0.453370  0.566847  1.000000
# Triples             -0.251118 -0.070072  0.435422  0.478694  0.220490
# Home Run             0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks                0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeout            0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Bases Stolen        -0.157234  0.081367  0.372618  0.413444  0.195027
# Run average         -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned runs         -0.809435 -0.041245  0.309686  0.252489 -0.235531
# ...

# %%
plt.figure(figsize=(16,7))
sns.heatmap(data.corr(),annot=True,cmap='YlGnBu')

# %%
data.skew(axis=0,skipna=True)
# Out:
# Wins                   0.047089
# Runs                   1.200786
# At-Bat                 0.183437
# Hits                   0.670254
# Doubles               -0.230650
# Triples                0.129502
# Home Run               0.516441
# Walks                  0.158498
# Strikeout             -0.156065
# Bases Stolen           0.479893
# Run average            0.045734
# Earned runs            0.058710
# Earned runs average    0.053331
# Complete game          0.736845
# Shutout                0.565790
# Save                   0.657524
# Error                  0.890132
# dtype: float64

# %%
plt.figure(figsize=(16,7))
data.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
X=data.drop('Wins',axis=1)
y=data["Wins"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
pred=model.predict(X_test)
pred
# Out:
# array([87.02257692, 98.0643169 , 67.10146206, 97.64218428, 85.31305103,
#        80.79052064, 78.88826498, 56.96031712, 79.36016321])

# %%
from sklearn.metrics import r2_score
score=r2_score(model.predict(X_test),y_test)
score
# Out:
# 0.8595591084124222

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor()
parameters={'n_neighbors':(1,10)}
gd=GridSearchCV(kn,parameters,cv=10)
gd.fit(X_train,y_train)
gd.best_params_
# Out:
# {'n_neighbors': 10}

# %%
from sklearn.model_selection import GridSearchCV
dt=DecisionTreeRegressor()
parameters={'criterion':('mse','mae','friedman_mse')}
gd=GridSearchCV(dt,parameters)
gd.fit(X_train,y_train)
gd.best_params_
# Out:
# {'criterion': 'mse'}

# %%
from sklearn.linear_model import Lasso

# %%
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(X,y)
clf.best_params_
# Out:
# {'alpha': 0.01}

# %%
model=[]
score=[]
cvs=[]
for i in [LinearRegression(),KNeighborsRegressor(n_neighbors=10),DecisionTreeRegressor(criterion='mse'),Lasso(alpha=0.001)]:
    k=i
    model.append(i)
    print("\n")
    print("model calculation for ",i,"are:")
    k.fit(X_train,y_train)
    k.score(X_train,y_train)
    pred=k.predict(X_test)
    print(pred)
    rscore=r2_score(k.predict(X_test),y_test)
    print("r2 score is",rscore)
    score.append(rscore)
    cv_score=cross_val_score(k,X,y,cv=5).mean()
    print('cv score is',cv_score)
    cvs.append(cv_score)
# Out:
# model calculation for  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) are:
# [87.02257692 98.0643169  67.10146206 97.64218428 85.31305103 80.79052064
#  78.88826498 56.96031712 79.36016321]
# r2 score is 0.8595591084124222
# cv score is 0.04075540667465847
#
#
# model calculation for  KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform') are:
# [79.7 86.8 77.1 86.1 81.8 79.7 77.7 73.6 82.4]
# r2 score is -2.6957667486170864
# cv score is -0.2680004389650542
#
#
# model calculation for  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
# ...

# %%
result=pd.DataFrame({'Model':['LinearRegression','KNeighborsRegressor','DecisionTreeRegressor','Lasso'],'R2 score':[0.884687057195993,-4.04177432485045, 0.18762968874700714,0.884560857561289],'CV score':[0.3741799046419861,-0.4404276612549422,-2.309084473575619,0.37395638187865254]})
result
# Out:
#                    Model  R2 score  CV score
# 0       LinearRegression  0.884687  0.374180
# 1    KNeighborsRegressor -4.041774 -0.440428
# 2  DecisionTreeRegressor  0.187630 -2.309084
# 3                  Lasso  0.884561  0.373956

# %%
#Linear regression is the best model . So we are saving it

# %%
from sklearn.externals import joblib 
  

joblib.dump(model,'baseball.pkl') 
  
model_from_joblib = joblib.load('baseball.pkl')
